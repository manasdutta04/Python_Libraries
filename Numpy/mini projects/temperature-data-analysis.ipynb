# %% [markdown]
# ### Temperature Data Analysis
#
# **What to build**
#
# - Daily temperature data for a month
# - Find:
#     - Hottest & coldest day
#     - Weekly average temperature
#     - Days above average
#
# **NumPy concepts**
#
# - Slicing
# - `where()`
# - Aggregations
# - Reshaping

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
import random
temps = np.random.uniform(15, 45, 30)
dates = np.arange(1, 31)

for temp, date in zip(temps, dates):
    print(f"Day: {date} --> Temperature: {temp:.2f} C")
# Out:
# Day: 1 --> Temperature: 28.03 C
# Day: 2 --> Temperature: 22.61 C
# Day: 3 --> Temperature: 27.16 C
# Day: 4 --> Temperature: 32.14 C
# Day: 5 --> Temperature: 37.23 C
# Day: 6 --> Temperature: 38.02 C
# Day: 7 --> Temperature: 39.68 C
# Day: 8 --> Temperature: 37.33 C
# Day: 9 --> Temperature: 35.43 C
# Day: 10 --> Temperature: 22.13 C
# Day: 11 --> Temperature: 27.01 C
# Day: 12 --> Temperature: 29.33 C
# Day: 13 --> Temperature: 17.49 C
# Day: 14 --> Temperature: 30.85 C
# Day: 15 --> Temperature: 28.09 C
# Day: 16 --> Temperature: 39.06 C
# Day: 17 --> Temperature: 44.34 C
# Day: 18 --> Temperature: 31.68 C
# Day: 19 --> Temperature: 24.68 C
# Day: 20 --> Temperature: 16.30 C
# Day: 21 --> Temperature: 42.74 C
# Day: 22 --> Temperature: 42.57 C
# Day: 23 --> Temperature: 22.59 C
# Day: 24 --> Temperature: 35.86 C
# Day: 25 --> Temperature: 17.26 C
# Day: 26 --> Temperature: 19.99 C
# Day: 27 --> Temperature: 21.50 C
# Day: 28 --> Temperature: 23.83 C
# Day: 29 --> Temperature: 44.87 C
# Day: 30 --> Temperature: 35.91 C
